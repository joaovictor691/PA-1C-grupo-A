# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovictor691/PA-1C-grupo-A/blob/main/aula_dia_27_4_1c_gp_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("OLá MUNDO!")
print ("OLá MUNDO!")
print ("OLá MUNDO!")
# Out:
# OLá MUNDO!

# %%
for i in range(5):
  print ("olá mundo")
# Out:
# olá mundo
# olá mundo
# olá mundo
# olá mundo
# olá mundo

# %%
for i in range(1,6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(7):
  print (6-i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#numeros pares de 0 a 10

for i in range(0, 11, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#nmeros impares de 1 a 9
for i in range(1, 11, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#escrever um programa que o usuario digita um numero de 0 a 10 e impreme a tabuada

try:
  numero_digitado = int(input("Escolha um número de 0 a 10 para ver a tabuada: "))

  if 0 <= numero_digitado <= 10:
    print(f"Tabuada do {numero_digitado}:")

    for i in range(1, 11):
      print(f"{numero_digitado} x {i} = {numero_digitado * i}")
  else:
    print("Número inválido. Por favor, digite um número entre 0 e 10.")
except ValueError:
  print("Entrada inválida. Por favor, digite um número inteiro.")
# Out:
# Escolha um número de 0 a 10 para ver a tabuada: 3
# Tabuada do 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
A= int(input("Digite o número:  "))
for i in range (1,11) :
 print(f"{A} x {i} = {A * i} 67 ")
# Out:
# Digite o número:  6
# 6 x 1 = 6 67
# 6 x 2 = 12 67
# 6 x 3 = 18 67
# 6 x 4 = 24 67
# 6 x 5 = 30 67
# 6 x 6 = 36 67
# 6 x 7 = 42 67
# 6 x 8 = 48 67
# 6 x 9 = 54 67
# 6 x 10 = 60 67
