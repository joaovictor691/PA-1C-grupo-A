# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovictor691/PA-1C-grupo-A/blob/main/AULA_DIA_23_03_PA_1C_GRUPO_AI_PYNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input("digite um número: "))
b = int (input("digite um número: "))

if a > b:
    print(F"{a} maior que {b}")

else:
    print (f"{b} maior que {a}")
# Out:
# digite um número: 10
# digite um número: 20
# 20 maior que 10

# %%
# escrever um programa que verifica se o usuario é maior de idade

nome = input("digite seu nome: ")
iDADE = int(input("digite sua idade: "))

if iDADE >= 18:
    print("maior de idade")
    print(f"{nome} você é maior de idade")
else:
    print("menor de idade")
    print(f"{nome} você é menor de idade")
# Out:
# digite seu nome: joao victor
# digite sua idade: 18
# maior de idade
# joao victor você é maior de idade

# %%
# escrever programa que verifica se um numero é par ou impar.

numero = int(input("DIGITE UM NUMERO:"))

if numero % 2 == 0:
    print("NUMERO PAR")
else:
    print("NUMERO IMPAR")
# Out:
# DIGITE UM NUMERO:0
# NUMERO PAR

# %%
# escrever um programa que verifica se o numero é maior que 10.

numero = int(input("DIGITE UM NUMERO:"))

if numero >= 10:

    print(f"{numero} é maior que 10")
else:
    print("NUMERO MENOR QUE 10")
# Out:
# DIGITE UM NUMERO:10
# 10 é maior que 10

# %%
# escrever um programa que :
# peça o valor da compra
# se o valor for maior que 100, aplique um desconto de 15%
# se não mostre o valor normal.

valor = float(input("DIGITE O VALOR DA COMPRA:"))

if valor > 100:
    desconto = valor * 0.15
    valor_final = valor - desconto
    print(f"VALOR COM DESCONTO: {valor_final}")
else:
    print(f"VALOR SEM DESCONTO: {valor}")
# Out:
# DIGITE O VALOR DA COMPRA:465
# VALOR COM DESCONTO: 395.25

# %%
#escreverr um programa que verifica uma senha simoles, senha == 251202luli, saida acesso permitido

senha = input("DIGITE A SENHA:")

if senha == "251202luli":
    print("ACESSO PERMITIDO")
else:
    print("ACESSO NEGADO")

    senha = input("DIGITE A SENHA:")

if senha == "251202luli":
    print("ACESSO PERMITIDO")
# Out:
# DIGITE A SENHA:251202
# ACESSO NEGADO
# DIGITE A SENHA:251202

# %%
# escrever um programa que o aluno digita 04 notas dos bimestre e o programa calcula a media e mostra na saida se o aluno foi aprovado, recuperação ou reprovado

nota1 = float(input("DIGITE A PRIMEIRA NOTA:"))
nota2 = float(input("DIGITE A SEGUNDA NOTA:"))
nota3 = float(input("DIGITE A TERCEIRA NOTA:"))
nota4 = float(input("DIGITE A QUARTA NOTA:"))

MEDIA = (nota1 + nota2 + nota3 + nota4) / 4

if MEDIA >= 10:
    print(f"PARABENS!!! APROVADO SUA MEDIA FOI: {MEDIA}")
elif MEDIA >= 4.5:
    prin1t(f"APROVADO SUA MEDIA FOI: {MEDIA}")
elif MEDIA >= 3.5:
    print(f"RECUPERAÇÃO SUA MEDIA FOI: {MEDIA}")
else:
    print(f"REPROVADO SUA MEDIA FOI: {MEDIA}")
# Out:
# DIGITE A PRIMEIRA NOTA:10
# DIGITE A SEGUNDA NOTA:10
# DIGITE A TERCEIRA NOTA:10
# DIGITE A QUARTA NOTA:10
# PARABENS!!! APROVADO SUA MEDIA FOI: 10.0
